# %%
import pandas as pd
import seaborn as sns

# %%
import pandas as pd
vc=pd.read_csv("HRDataset_v14.csv")
vc
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
vc.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
vc.shape
# Out:
# (311, 36)

# %%
vc=pd.read_csv("HRDataset_v14.csv",index_col=0)

# %%
vc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 311 entries, Adinolfi, Wilson  K to Zima, Colleen
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   EmpID                       311 non-null    int64
#  1   MarriedID                   311 non-null    int64
#  2   MaritalStatusID             311 non-null    int64
#  3   GenderID                    311 non-null    int64
#  4   EmpStatusID                 311 non-null    int64
#  5   DeptID                      311 non-null    int64
#  6   PerfScoreID                 311 non-null    int64
#  7   FromDiversityJobFairID      311 non-null    int64
#  8   Salary                      311 non-null    int64
#  9   Termd                       311 non-null    int64
#  10  PositionID                  311 non-null    int64
#  11  Position                    311 non-null    object
#  12  State                       311 non-null    object
# ...

# %%
print(vc.duplicated().to_string())
# Out:
# Employee_Name
# Adinolfi, Wilson  K          False
# Ait Sidi, Karthikeyan        False
# Akinkuolie, Sarah            False
# Alagbe,Trina                 False
# Anderson, Carol              False
# Anderson, Linda              False
# Andreola, Colby              False
# Athwal, Sam                  False
# Bachiochi, Linda             False
# Bacong, Alejandro            False
# Baczenski, Rachael           False
# Barbara, Thomas              False
# Barbossa, Hector             False
# Barone, Francesco  A         False
# Barton, Nader                False
# Bates, Norman                False
# Beak, Kimberly               False
# Beatrice, Courtney           False
# Becker, Renee                False
# Becker, Scott                False
# Bernstein, Sean              False
# Biden, Lowan  M              False
# Billis, Helen                False
# Blount, Dianna               False
# Bondwell, Betsy              False
# Booth, Frank                 False
# ...

# %%
print(vc.drop_duplicates().to_string())
# Out:
#                            EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  PositionID                      Position State    Zip       DOB Sex MaritalDesc          CitizenDesc HispanicLatino                          RaceDesc  DateofHire DateofTermination                        TermReason        EmploymentStatus            Department         ManagerName  ManagerID        RecruitmentSource   PerformanceScore  EngagementSurvey  EmpSatisfaction  SpecialProjectsCount LastPerformanceReview_Date  DaysLateLast30  Absences
# Employee_Name
# ...

# %%
vc.MarriedID.dtype
# Out:
# dtype('int64')

# %%
vc['MarriedID'].value_counts().head()
# Out:
# 0    187
# 1    124
# Name: MarriedID, dtype: int64

# %%
vc['MarriedID'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
vc['MarriedID'].nunique()
# Out:
# 2

# %%
vc['MarriedID'].describe()
# Out:
# count    311.000000
# mean       0.398714
# std        0.490423
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: MarriedID, dtype: float64

# %%
vc['Salary'].min()
# Out:
# 45046

# %%
vc['Salary'].max()
# Out:
# 250000

# %%
vc.dropna(inplace=True)

# %%
vc.isnull().sum()
# Out:
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# PerformanceScore              0
# ...

# %%
vc
# Out:
#                           EmpID  MarriedID  MaritalStatusID  GenderID  \
# Employee_Name
# Ait Sidi, Karthikeyan     10084          1                1         1
# Akinkuolie, Sarah         10196          1                1         0
# Anderson, Carol           10069          0                2         0
# Baczenski, Rachael        10252          1                1         0
# Barbara, Thomas           10242          1                1         1
# ...                         ...        ...              ...       ...
# Wilber, Barry             10048          1                1         1
# Wilkes, Annie             10204          0                2         0
# Williams, Jacquelyn       10264          0                0         0
# Winthrop, Jordan          10033          0                0         1
# Ybarra, Catherine         10301          0                0         0
#
#                           EmpStatusID  DeptID  PerfScoreID  \
# Employee_Name
# ...

# %%
vc=vc.drop(['ManagerName','RecruitmentSource','Sex','PerformanceScore','State','DateofTermination','DOB','TermReason','MaritalDesc','CitizenDesc','HispanicLatino','DateofHire','RaceDesc','LastPerformanceReview_Date'],axis=1)
vc
# Out:
#                           EmpID  MarriedID  MaritalStatusID  GenderID  \
# Employee_Name
# Ait Sidi, Karthikeyan     10084          1                1         1
# Akinkuolie, Sarah         10196          1                1         0
# Anderson, Carol           10069          0                2         0
# Baczenski, Rachael        10252          1                1         0
# Barbara, Thomas           10242          1                1         1
# ...                         ...        ...              ...       ...
# Wilber, Barry             10048          1                1         1
# Wilkes, Annie             10204          0                2         0
# Williams, Jacquelyn       10264          0                0         0
# Winthrop, Jordan          10033          0                0         1
# Ybarra, Catherine         10301          0                0         0
#
#                           EmpStatusID  DeptID  PerfScoreID  \
# Employee_Name
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
vc["Department"]=LE.fit_transform(vc["Department"])
vc["EmploymentStatus"]=LE.fit_transform(vc["EmploymentStatus"])
vc["Position"]=LE.fit_transform(vc["Position"])
vc
# Out:
#                           EmpID  MarriedID  MaritalStatusID  GenderID  \
# Employee_Name
# Ait Sidi, Karthikeyan     10084          1                1         1
# Akinkuolie, Sarah         10196          1                1         0
# Anderson, Carol           10069          0                2         0
# Baczenski, Rachael        10252          1                1         0
# Barbara, Thomas           10242          1                1         1
# ...                         ...        ...              ...       ...
# Wilber, Barry             10048          1                1         1
# Wilkes, Annie             10204          0                2         0
# Williams, Jacquelyn       10264          0                0         0
# Winthrop, Jordan          10033          0                0         1
# Ybarra, Catherine         10301          0                0         0
#
#                           EmpStatusID  DeptID  PerfScoreID  \
# Employee_Name
# ...

# %%
x=vc.drop(['Salary'],axis=1)
x
# Out:
#                           EmpID  MarriedID  MaritalStatusID  GenderID  \
# Employee_Name
# Ait Sidi, Karthikeyan     10084          1                1         1
# Akinkuolie, Sarah         10196          1                1         0
# Anderson, Carol           10069          0                2         0
# Baczenski, Rachael        10252          1                1         0
# Barbara, Thomas           10242          1                1         1
# ...                         ...        ...              ...       ...
# Wilber, Barry             10048          1                1         1
# Wilkes, Annie             10204          0                2         0
# Williams, Jacquelyn       10264          0                0         0
# Winthrop, Jordan          10033          0                0         1
# Ybarra, Catherine         10301          0                0         0
#
#                           EmpStatusID  DeptID  PerfScoreID  \
# Employee_Name
# ...

# %%
y=vc["Salary"]
y
# Out:
# Employee_Name
# Ait Sidi, Karthikeyan       104437
# Akinkuolie, Sarah            64955
# Anderson, Carol              50825
# Baczenski, Rachael           54670
# Barbara, Thomas              47211
#                              ...
# Wilber, Barry                55140
# Wilkes, Annie                58062
# Williams, Jacquelyn          59728
# Winthrop, Jordan             70507
# Ybarra, Catherine            48513
# Name: Salary, Length: 104, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor
dc=DecisionTreeRegressor()
dc.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dc.predict(x_test)                                 
y_pred
# Out:
# array([ 59370., 100416.,  60070.,  74326.,  45115.,  55722.,  52674.,
#         46664.,  61729.,  59370.,  64066.,  74669.,  58523.,  50428.,
#         59370.,  59370., 100416.,  64066.,  74326.,  59369.,  54933.,
#         46664.,  61422.,  68182.,  74669.,  64955.,  63515.,  52177.,
#         74326.,  60070.,  57748.,  59124.,  74312., 100416.,  63478.])

# %%
print('MAE:',metrics.mean_absolute_error(y_test,y_pred))
print('MSE:',metrics.mean_squared_error(y_test,y_pred))
DTR=np.sqrt(metrics.mean_absolute_error(y_test,y_pred))
DTR
# Out:
# MAE: 11663.314285714287
# MSE: 271432085.6
# 107.99682535016613

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()                                          
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([ 24917.0871821 ,  89951.24354254,  55335.16448094, 117634.80714212,
#         63287.41648408,  61984.00521897,  51111.17888547,  57757.83562345,
#         59618.31879092,  48066.24069415,  58824.49698727,  69500.97862899,
#         60992.80933943,  61732.2627947 , 108093.23687951,  97613.20817287,
#         93547.30959851,  56309.88760825,  68246.94365419,  61014.00185351,
#         54742.41204617,  58858.02130571,  65334.35167297,  63924.97641559,
#        115220.16331955,  56463.78853623,  46221.69294533,  59130.43437309,
#        103144.1205767 ,  51888.71888253,  56867.59135682,  68727.13447627,
#        108747.75159247,  46131.93473598,  61443.61826163])

# %%
from sklearn import metrics                   
import numpy as np

# %%
print('MAE:',metrics.mean_absolute_error(y_test,y_pred))
print('MSE:',metrics.mean_squared_error(y_test,y_pred))
LR=np.sqrt(metrics.mean_absolute_error(y_test,y_pred))
LR
# Out:
# MAE: 12418.948128537111
# MSE: 330219112.18553025
# 111.44033438812498

# %%
from sklearn.svm import SVR
dc=SVR()
dc.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred=dc.predict(x_test)
y_pred
# Out:
# array([60069.9992033 , 60069.96539239, 60069.98705204, 60070.03342055,
#        60070.0012825 , 60069.96317525, 60069.9677415 , 60069.99858217,
#        60069.98292907, 60069.96821951, 60069.96797956, 60070.01077862,
#        60069.96533387, 60069.9611313 , 60069.97724905, 60069.98422942,
#        60069.95968565, 60069.98525872, 60070.42600359, 60069.99019135,
#        60069.98713257, 60070.00847374, 60069.96907346, 60069.96903661,
#        60070.00860868, 60069.98494516, 60069.97878478, 60069.96263776,
#        60069.96531864, 60069.9860929 , 60070.0091324 , 60069.96819496,
#        60069.94135842, 60069.97844459, 60069.98762179])

# %%
print('MAE:',metrics.mean_absolute_error(y_test,y_pred))
print('MSE:',metrics.mean_squared_error(y_test,y_pred))
SVR=np.sqrt(metrics.mean_absolute_error(y_test,y_pred))
SVR
# Out:
# MAE: 13931.703350656671
# MSE: 407188795.7336793
# 118.03263680294816

# %%
from sklearn.ensemble import RandomForestRegressor
lr=RandomForestRegressor(n_estimators=3,random_state=0)
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([60071.        , 89643.66666667, 52062.33333333, 79295.66666667,
#        53474.33333333, 61203.66666667, 57979.33333333, 45795.        ,
#        60395.        , 70045.        , 65644.        , 55921.        ,
#        51538.66666667, 52051.33333333, 89541.33333333, 81410.66666667,
#        96438.        , 72575.        , 74321.33333333, 58275.        ,
#        50058.66666667, 46992.        , 54966.        , 66107.33333333,
#        67590.        , 70834.33333333, 57641.33333333, 52318.33333333,
#        85160.        , 58824.        , 52124.33333333, 56962.33333333,
#        68431.        , 92351.66666667, 62514.        ])

# %%
print('MAE:',metrics.mean_absolute_error(y_test,y_pred))
print('MSE:',metrics.mean_squared_error(y_test,y_pred))
RF=np.sqrt(metrics.mean_absolute_error(y_test,y_pred))
RF
# Out:
# MAE: 9473.695238095237
# MSE: 163407331.0031746
# 97.33290932719127

# %%
model=pd.DataFrame({
    'model':['linearRegression','DecisionTreeRegressor','RandomForestRegressor','SVR'],
    'accuracyscore':[LR,DTR,RF,SVR]
})
model
sns.barplot(x='accuracyscore',y='model',data=model)
model.sort_values(by='accuracyscore',ascending=False)
# Out:
#                    model  accuracyscore
# 3                    SVR     118.032637
# 0       linearRegression     111.440334
# 1  DecisionTreeRegressor     107.996825
# 2  RandomForestRegressor      97.332909
